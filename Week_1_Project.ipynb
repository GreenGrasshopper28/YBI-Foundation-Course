# %% [markdown]
# <a href="https://colab.research.google.com/github/GreenGrasshopper28/YBI-Foundation-Course/blob/main/Week_1_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHEAT SHEET FOR PANDAS

# %%
import pandas as pd

# %%
df=pd.DataFrame(
    {
        "a":[4,5,6],
         "b":[7,8,9],
     "c":[10,11,12]
    },index=[1,2,3]
)

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
ef=pd.DataFrame(
    [[4,7,10],[5,8,11],[6,9,12]],
    index=["a","b","c"],columns=[1,2,3]
)
ef
# Out:
#    1  2   3
# a  4  7  10
# b  5  8  11
# c  6  9  12

# %%
df=pd.DataFrame(
    { "a":[4,5,6],
      "b":[7,8,9],
      "c":[10,11,12]}, 
      index=pd.MultiIndex.from_tuples([('x',1),('y',2),('z',3)], names=['m','n']))
df
# Out:
#      a  b   c
# m n
# x 1  4  7  10
# y 2  5  8  11
# z 3  6  9  12

# %%
af=pd.DataFrame(
    {
        "a":[4,5,6],
         "b":[7,8,9],
     "c":[10,11,12]
    },index=[1,2,3]
)

# %%
bf=pd.DataFrame(
    {
        "a":[24,25,26],
         "b":[27,28,29],
     "c":[30,31,32]
    },index=[1,2,3]
)
bf
# Out:
#     a   b   c
# 1  24  27  30
# 2  25  28  31
# 3  26  29  32

# %%
cd=pd.melt(bf)
cd
# Out:
#   variable  value
# 0        a     24
# 1        a     25
# 2        a     26
# 3        b     27
# 4        b     28
# 5        b     29
# 6        c     30
# 7        c     31
# 8        c     32

# %%
pd.concat([af,bf])
# Out:
#     a   b   c
# 1   4   7  10
# 2   5   8  11
# 3   6   9  12
# 1  24  27  30
# 2  25  28  31
# 3  26  29  32

# %%
pd.concat([af,bf],axis=1)
# Out:
#    a  b   c   a   b   c
# 1  4  7  10  24  27  30
# 2  5  8  11  25  28  31
# 3  6  9  12  26  29  32

# %%
bf.pivot(columns=['a','b','c'],values=['a','b','c'])
# Out:
#       a                 b                 c
# a    24    25    26    24    25    26    24    25    26
# b    27    28    29    27    28    29    27    28    29
# c    30    31    32    30    31    32    30    31    32
# 1  24.0   NaN   NaN  27.0   NaN   NaN  30.0   NaN   NaN
# 2   NaN  25.0   NaN   NaN  28.0   NaN   NaN  31.0   NaN
# 3   NaN   NaN  26.0   NaN   NaN  29.0   NaN   NaN  32.0

# %%
bf
# Out:
#     a   b   c
# 1  24  27  30
# 2  25  28  31
# 3  26  29  32

# %%
af
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
af.sort_index(ascending=False)
# Out:
#    a  b   c
# 3  6  9  12
# 2  5  8  11
# 1  4  7  10

# %%
bf.sort_values('a',ascending=False)
# Out:
#     a   b   c
# 3  26  29  32
# 2  25  28  31
# 1  24  27  30

# %%
bf.reset_index()
# Out:
#    index   a   b   c
# 0      1  24  27  30
# 1      2  25  28  31
# 2      3  26  29  32

# %%
af.drop(columns=['c'])
# Out:
#    a  b
# 1  4  7
# 2  5  8
# 3  6  9

# %%
bf[bf.a%2==0]
# Out:
#     a   b   c
# 1  24  27  30
# 3  26  29  32

# %%
af.drop_duplicates()
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
bf.sample(frac=0.7)
# Out:
#     a   b   c
# 2  25  28  31
# 3  26  29  32

# %%
kf=pd.read_csv('https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Titanic.csv')

# %%
kf.sample(n=14)
# Out:
#       pclass  survived                                             name  \
# 841        3         0                             Hagardon, Miss. Kate
# 536        2         1                              Pinsky, Mrs. (Rosa)
# 975        3         0  Lobb, Mrs. William Arthur (Cordelia K Stanlick)
# 1191       3         0                   Saundercock, Mr. William Henry
# 1037       3         1                   Moussa, Mrs. (Mantoura Boulos)
# 641        3         1                Asplund, Master. Edvin Rojj Felix
# 1178       3         0                         Sage, Mr. George John Jr
# 1153       3         0   Robins, Mrs. Alexander A (Grace Charity Laury)
# 666        3         0                  Barbara, Mrs. (Catherine David)
# 315        1         1                         Willard, Miss. Constance
# 161        1         1             Hogeboom, Mrs. John C (Anna Andrews)
# 55         1         1                        Carter, Miss. Lucile Polk
# ...

# %%
kf.nlargest(10,'age')
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 9          1         0                            Artagaveytia, Mr. Ramon
# 135        1         0                          Goldschmidt, Mr. George B
# 727        3         0                               Connors, Mr. Patrick
# 81         1         0                       Crosby, Capt. Edward Gifford
# 506        2         0                        Mitchell, Mr. Henry Michael
# 285        1         0                                 Straus, Mr. Isidor
# 594        2         0                              Wheadon, Mr. Edward H
#
#          sex   age  sibsp  parch      ticket      fare    cabin embarked boat  \
# ...

# %%
kf.nsmallest(10,'age')
# Out:
#       pclass  survived                                     name     sex   age  \
# 763        3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.17
# 747        3         0  Danbom, Master. Gilbert Sigvard Emanuel    male  0.33
# 1240       3         1          Thomas, Master. Assad Alexander    male  0.42
# 427        2         1                Hamalainen, Master. Viljo    male  0.67
# 657        3         1                   Baclini, Miss. Eugenie  female  0.75
# 658        3         1            Baclini, Miss. Helene Barbara  female  0.75
# 1111       3         0           Peacock, Master. Alfred Edward    male  0.75
# 359        2         1            Caldwell, Master. Alden Gates    male  0.83
# 548        2         1          Richards, Master. George Sibley    male  0.83
# 611        3         1                Aks, Master. Philip Frank    male  0.83
#
#       sibsp  parch              ticket     fare cabin embarked boat  body  \
# ...

# %%
kf.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
kf.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
kf.filter(regex='age').head ()
# Out:
#      age
# 0  29.00
# 1   0.92
# 2   2.00
# 3  30.00
# 4  25.00

# %%
kf.query('pclass==3 and sibsp==1')
# Out:
#       pclass  survived                                             name  \
# 602        3         0                      Abbott, Mr. Rossmore Edward
# 603        3         1                 Abbott, Mrs. Stanton (Rosa Hunt)
# 610        3         0   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 621        3         1  Andersen-Jensen, Miss. Carla Christine Nielsine
# 629        3         0                      Andersson, Mr. Anders Johan
# ...      ...       ...                                              ...
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1299       3         0                              Yasbeck, Mr. Antoni
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch     ticket     fare cabin embarked boat  \
# ...

# %%
kf.loc[10:20,['age','name']]
# Out:
#      age                                               name
# 10  47.0                             Astor, Col. John Jacob
# 11  18.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12  24.0                      Aubart, Mme. Leontine Pauline
# 13  26.0                       Barber, Miss. Ellen "Nellie"
# 14  80.0               Barkworth, Mr. Algernon Henry Wilson
# 15   NaN                                Baumann, Mr. John D
# 16  24.0                           Baxter, Mr. Quigg Edmond
# 17  50.0    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18  32.0                              Bazzani, Miss. Albina
# 19  36.0                               Beattie, Mr. Thomson
# 20  37.0                      Beckwith, Mr. Richard Leonard

# %%
kf.iloc[20:30,[0,2,4,8]]
# Out:
#     pclass                                              name   age      fare
# 20       1                     Beckwith, Mr. Richard Leonard  37.0   52.5542
# 21       1  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0   52.5542
# 22       1                             Behr, Mr. Karl Howell  26.0   30.0000
# 23       1                             Bidois, Miss. Rosalie  42.0  227.5250
# 24       1                                 Bird, Miss. Ellen  29.0  221.7792
# 25       1                               Birnbaum, Mr. Jakob  25.0   26.0000
# 26       1                           Bishop, Mr. Dickinson H  25.0   91.0792
# 27       1           Bishop, Mrs. Dickinson H (Helen Walton)  19.0   91.0792
# 28       1                            Bissette, Miss. Amelia  35.0  135.6333
# 29       1         Bjornstrom-Steffansson, Mr. Mauritz Hakan  28.0   26.5500

# %%
kf.iat[14,2]
# Out:
# 'Barkworth, Mr. Algernon Henry Wilson'

# %%
kf.at[21,'name']
# Out:
# 'Beckwith, Mrs. Richard Leonard (Sallie Monypeny)'

# %%
kf.value_counts
# Out:
# <bound method DataFrame.value_counts of       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
# ...

# %%
kf['pclass'].value_counts ()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
kf.shape
# Out:
# (1309, 14)

# %%
len(kf)
# Out:
# 1309

# %%
kf['pclass'].nunique()
# Out:
# 3

# %%
kf.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
vf=kf.groupby(by="pclass")
vf

# %%
vf.size()
# Out:
# pclass
# 1    323
# 2    277
# 3    709
# dtype: int64

# %%
vf.agg('pclass')

# %%
vf.cummax()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: Dropping invalid columns in DataFrameGroupBy.cummax is deprecated. In a future version, a TypeError will be raised. Before calling .cummax, select only columns which should be valid for the transforming function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       survived   age  sibsp  parch      fare   body
# 0            1  29.0      0      0  211.3375    NaN
# 1            1  29.0      1      2  211.3375    NaN
# 2            1  29.0      1      2  211.3375    NaN
# 3            1  30.0      1      2  211.3375  135.0
# 4            1  30.0      1      2  211.3375    NaN
# ...        ...   ...    ...    ...       ...    ...
# 1304         1  74.0      8      9   69.5500  328.0
# 1305         1   NaN      8      9   69.5500    NaN
# 1306         1  74.0      8      9   69.5500  328.0
# 1307         1  74.0      8      9   69.5500    NaN
# ...

# %%
vf.cumsum()
# Out:
#       survived       age  sibsp  parch       fare    body
# 0            1     29.00      0      0   211.3375     NaN
# 1            2     29.92      1      2   362.8875     NaN
# 2            2     31.92      2      4   514.4375     NaN
# 3            2     61.92      3      6   665.9875   135.0
# 4            2     86.92      4      8   817.5375     NaN
# ...        ...       ...    ...    ...        ...     ...
# 1304       181  12350.50    402    284  9381.6660  8266.0
# 1305       181       NaN    403    284  9396.1202     NaN
# 1306       181  12377.00    403    284  9403.3452  8570.0
# 1307       181  12404.00    403    284  9410.5702     NaN
# 1308       181  12433.00    403    284  9418.4452     NaN
#
# [1309 rows x 6 columns]

# %%
kf.expanding
# Out:
# <bound method NDFrame.expanding of       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
# ...

# %%
kf.rolling(3)
# Out:
# Rolling [window=3,center=False,axis=0,method=single]

# %%
kf.plot.hist()

# %%
kf.plot.scatter(x='pclass',y='age')

# %%
pd.merge(af, bf,how='left', on='a')
# Out:
#    a  b_x  c_x  b_y  c_y
# 0  4    7   10  NaN  NaN
# 1  5    8   11  NaN  NaN
# 2  6    9   12  NaN  NaN

# %%
pd.merge(af, bf,
how='right', on='a')
# Out:
#     a  b_x  c_x  b_y  c_y
# 0  24  NaN  NaN   27   30
# 1  25  NaN  NaN   28   31
# 2  26  NaN  NaN   29   32

# %%
pd.merge(af, bf,
how='inner', on='a')
# Out:
# Empty DataFrame
# Columns: [a, b_x, c_x, b_y, c_y]
# Index: []

# %%
pd.merge(af, bf,
how='outer', on='a')
# Out:
#     a  b_x   c_x   b_y   c_y
# 0   4  7.0  10.0   NaN   NaN
# 1   5  8.0  11.0   NaN   NaN
# 2   6  9.0  12.0   NaN   NaN
# 3  24  NaN   NaN  27.0  30.0
# 4  25  NaN   NaN  28.0  31.0
# 5  26  NaN   NaN  29.0  32.0

# %%
af[af.a.isin(bf.a)]
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
af[~af.a.isin(bf.a)]
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12
